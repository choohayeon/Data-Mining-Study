# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3], [2,4,6])

plt.title ("Hello plot")

plt.show()

# %%
plt.figure(figsize=(10,4))

plt.plot([1,2,3],[2,4,6])
plt.title("Hello plot")
plt.show()

figure = plt.figure(figsize=(10,4))
print(type(figure))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
plt.figure(figsize=(4,4), facecolor='yellow')
plt.plot([1,2,3],[2,4,6])
plt.title("Hello plt")
plt.show()

# %%
ax = plt.axes()
print(type(ax))
#pyplot모듈이 import되어 있는 상태 - 별도의 plt.show()가 없더라도 Axes가 할당되어 있으면 자동으로 plt.show()와 같은 역할 가진 함수 호출
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %% [markdown]
# #### plt.subplots() pyplot에서 figure와 axes 객체 함께 가져오기
# - subplots() 함수는 인자는 여러 개의 axes를 설정가능

# %%
fig, ax = plt.subplots()
print('fig type:', type(fig), '/nax type:', type(ax))
# Out:
# fig type: <class 'matplotlib.figure.Figure'> /nax type: <class 'matplotlib.axes._subplots.AxesSubplot'>

# %% [markdown]
# axes 객체의 plot(), set_title() = pyplot의 plot(), title()

# %%
fig, ax = plt.subplots(figsize=(4,4))

ax.plot([1,2,3],[2,4,6])

ax.set_title('Hello plot')
plt.show()

# %% [markdown]
# #### 여러 개의 plot을 가지는 subplot 생성 : plt.shbplots()
# - plt.subplots(): 여러 개의 그래프를 그릴 수 있게 하는 1개의 Figure와 여러 개의 Axes를 생성
# > 개별 subplot은 하나의 axes를 가짐.
# > - plt.subplots 주요 인자: nrows, ncols, figsize
# >> - nrows: 전체 subplot들의 배치를 2차원의 행렬 형태로 표현할 때 행의 개수
# >> - ncols: 전체 subplot들의 배치를 2차원의 행렬 형태로 표현할 때 열의 개수
# >> - figsize: 모든 subplots들을 포함한 전체 figure의 크기를 설정

# %%
fig,(ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(6,3))

# %% [markdown]
# ### pyplot의 plot() 함수를 이용해 선 그리기
# 입력되는 x좌표 값 & y좌표 값의 개수 모든 같은 크기를 가져야 함

# %%
import numpy as np
import pandas as pd

x_value = [1,2,3,4]
y_value = [2,4,6,8]
#x_value = np.array([1,2,3,4])
#y_value = np.array([2,4,6,8])

plt.plot(x_value, y_value)
plt.show()

# %%
plt.plot(x_value, y_value, color='green')

# %%
plt.plot(x_value, y_value, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12)

# %% [markdown]
# 축 명칭 설정, 축의 눈금(틱)값 회전, 범례(legend) 설정하기

# %%
plt.plot(
    x_value, y_value, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12)

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
x_value = np.arange(0,100)
y_value = 2*x_value

plt.plot(x_value, y_value, color='green')
plt.xlabel('xaxis')
plt.ylabel('yaxis')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  ####  좀 더 세밀한 눈금 간격 표현

# %%
x_value = np.arange(0,100)
y_value = 2*x_value

plt.plot(x_value, y_value, color='green')
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.xticks(ticks=np.arange(0,100,5),rotation=90)

plt.title('Hello plot')
plt.show()

# %% [markdown]
# #### 범례(legend)
# - 여러 개의 그래프/차트를 한 Axes 내에서 표시할 때 이들을 구분하는데 사용
# - 여러 개의 플롯을 하나의 Axes 내에서 그릴 수 있음

# %%
x_value_01=np.arange(0,100)
y_value_01 = 2*x_value_01
y_value_02 = 4*x_value_01

plt.plot(x_value_01, y_value_01, color='green', label='green line')
plt.plot(x_value_01, y_value_02, color='red', label='red line')

plt.xlabel('x_axis')
plt.ylabel('y_axis')

plt.show()

# %%
x_value_01=np.arange(0,100)
y_value_01 = 2*x_value_01
y_value_02 = 4*x_value_01

plt.plot(x_value_01, y_value_01, color='green', label='green line')
plt.plot(x_value_01, y_value_02, color='red', label='red line')

plt.xlabel('x_axis')
plt.ylabel('y_axis')

plt.legend()

# %%
x_value_01 = np.arange(1,10)
y_value_01 = 2*x_value_01

plt.plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
plt.bar(x_value_01, y_value_01, color='green', label='bar plot')
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.legend()
plt.title('Hello plot')
plt.show()

# %%
figure = plt.figure()
ax = plt.axes()

ax.plot(x_value_01, y_value_01, color='red',marker='o', linestyle='dashed', label='red line')
ax.bar(x_value_01, y_value_01, color='green', label='bar plot')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

ax.legend()
ax.set_title('Hello plot')

plt.show()

# %% [markdown]
# ### 여러개의 subplots들을 이용해 개별 그래프를 supblot별로 시각화
# -  데이터 분석 측면에 유용
# -  서로 다른 피쳐 간의 그래프 비교 or 같은 피처라도 서로 다른 그래프를 이용해 여러 가지 특성들을 한 눈에 분석 가능
# > - 변환된 Axes 객체들을 가지는 ax 변수 : 튜플 X, 넘파이 ndarray 형태 ax[0]: 왼쪽에 생성된 Axes 객체, ax[1]: 오른쪽에 생성된 Axes 객체

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,3))

# %%
print('ax type:', type(ax))
print('ax[0]type:', type(ax[0]))
print('ax[1]type:', type(ax[1]))
# Out:
# ax type: <class 'numpy.ndarray'>
# ax[0]type: <class 'matplotlib.axes._subplots.AxesSubplot'>
# ax[1]type: <class 'matplotlib.axes._subplots.AxesSubplot'>

# %% [markdown]
# #### 여러 개의 sublplots들을 이용해 시각화 구현 시 유의사항
# - 개별  axes 객체를 직접 이용해서 시각화 구현

# %%
import numpy as np
x_value_01 = np.arange(1,10)
x_value_02 = np.arange(1,20)
y_value_01 = 2*x_value_01
y_value_02 = 2*x_value_02

fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(6,3))

ax[0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax[1].bar(x_value_02, y_value_02, color='green', label='bar plot')

ax[0].set_xlabel('ax[0] x axis')
ax[1].set_xlabel('ax[1] x axis')

ax[0].legend()
ax[1].legend()

ax[0].set_title('Hello line')
ax[1].set_title('Hello bar')

plt.show()

# %%
import numpy as np
x_value_01 = np.arange(1,10)
x_value_02 = np.arange(1,20)
y_value_01 = 2*x_value_01
y_value_02 = 2*x_value_02

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))


ax[0][0].plot(x_value_01, y_value_01, color= 'red', marker='o', linestyle='dashed', label='red line')
ax[0][1].bar(x_value_02, y_value_02, color='green', label='green bar')
ax[1][0].plot(x_value_01, y_value_01, color= 'green', marker='o', linestyle='dashed', label='green line')
ax[1][1].bar(x_value_02, y_value_02, color='red', label='red bar')

ax[0][0].set_xlabel('ax[0][0] x axis')
ax[0][1].set_xlabel('ax[0][1] x axis')
ax[1][0].set_xlabel('ax[1][0] x axis')
ax[1][1].set_xlabel('ax[1][1] x axis')

ax[0][0].legend()
ax[0][1].legend()
ax[1][0].legend()
ax[1][1].legend()
